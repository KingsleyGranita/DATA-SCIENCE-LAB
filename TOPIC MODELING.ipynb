# %%
import pandas as pd

# %%
text=pd.read_parquet("GenericMixOfTopic.parquet")

# %%
text.tail(10)
# Out:
#               id                                             title     topic  \
# 199995   8601409                                     Dharmaskandha     Mixed
# 199996   8573860                                              -ose     Mixed
# 199997    343429                                            Shudra       Law
# 199998  64414929  2016 Welsh Liberal Democrats leadership election     Mixed
# 199999   7024269                                 Nasmyth telescope   Science
# 200000  60141597                           Gerhard Müller-Hornbach     Mixed
# 200001  31530320                   2011 Balearic regional election     Mixed
# 200002  54223940                     Liberation Front of Andalusia  Politics
# 200003  50911071                                     Vlad Lisovets     Mixed
# 200004   1269453                            Greek National Road 44     Mixed
#
#                                   topics_with_percentages  \
# 199995  b'{"Philosophy":0.5,"Religion":0.5,"Academic_d...
# ...

# %%
text['text'].iloc[200002]
# Out:
# "  Liberation Front of Andalusia (in Spanish language|Spanish : Frente de Liberación de Andalucía) was an Andalusian nationalism|independentist and Revolutionary socialism|socialist party in Andalusia , Spain . History FLA was founded in 1978 by the Córdoba, Spain|Cordobés documentarist and ex-member of the Communist Party of Spain (PCE) Antonio Medina Molera. The party was also a result of the union of several splinter factions of various left movements; like the Unified Socialist Party of Andalusia (PSUA) or the Nationalist Left of Andalusia. In Catalonia the party had good relations with the Socialist Party of National Liberation (PSAN), and even gave support to the Left Bloc for National Liberation (BEAN) in the Catalan regional election, 1980|Catalan parliamentary elections of 1980 . FLA disappeared in 1980, and the majority of its members joined the Yama'a Islámica de Al-Andalus and, later, Andalusian Liberation . These new organizations wanted not only independence for Andalus
# ...

# %%
text.groupby(text['topic']).count()
# Out:
#                           id   title  topics_with_percentages    text
# topic
# Academic_disciplines     825     825                      825     825
# Business                 825     825                      825     825
# Communication            288     288                      288     288
# Concepts                 825     825                      825     825
# Culture                  825     825                      825     825
# Economy                  825     825                      825     825
# Education                825     825                      825     825
# Energy                   825     825                      825     825
# Engineering              825     825                      825     825
# Entertainment            825     825                      825     825
# Entities                 756     756                      756     756
# Ethics                   136     136                      136     136
# ...
